# %%
pip install tensorflow keras pickle nltk
# Out:
# Requirement already satisfied: tensorflow in c:\users\acer\anaconda3\lib\site-packages (2.5.0)
# Requirement already satisfied: keras in c:\users\acer\anaconda3\lib\site-packages (2.4.3)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
intents_file = open('/Users/acer/Desktop/intents.json').read()
intents = json.loads(intents_file)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)        
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# create the training data
training = []
# create empty array for the output
output_empty = [0] * len(classes)
# training set, bag of words for every sentence
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    word_patterns = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    # create the bag of words array with 1, if word is found in current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)
# create training and testing lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data is created")
# Out:
# Training data is created
# <ipython-input-8-8ba07a3fe07a>:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)

# %%
# deep neural networds model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#Training and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model is created")
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/200
# 10/10 [==============================] - 10s 2ms/step - loss: 2.2214 - accuracy: 0.1847
# Epoch 2/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1524 - accuracy: 0.1209
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1255 - accuracy: 0.2007
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0500 - accuracy: 0.2465
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9300 - accuracy: 0.3137
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.8445 - accuracy: 0.4287
# Epoch 7/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.6579 - accuracy: 0.5485
# Epoch 8/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.4574 - accuracy: 0.6526
# Epoch 9/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.3872 - accuracy: 0.6202
# Epoch 10/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.4049 - accuracy: 0.6857
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.2061 - accuracy: 0.5907
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0489 - accuracy: 0.7500
# Epoch 13/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9792 - accuracy: 0.7938
# Epoch 14/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8551 - accuracy: 0.7674
# Epoch 15/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8756 - accuracy: 0.7960
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6117 - accuracy: 0.8567
# Epoch 17/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5829 - accuracy: 0.9005
# Epoch 18/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5571 - accuracy: 0.9164
# Epoch 19/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4605 - accuracy: 0.8409
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5551 - accuracy: 0.8726
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5283 - accuracy: 0.8254
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3099 - accuracy: 0.9214
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4242 - accuracy: 0.8822
# Epoch 24/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4740 - accuracy: 0.9649
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3452 - accuracy: 0.9150
# Epoch 26/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.9425
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2792 - accuracy: 0.9440
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3930 - accuracy: 0.9167
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2938 - accuracy: 0.8945
# Epoch 30/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1423 - accuracy: 0.9787
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4407 - accuracy: 0.8282
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2538 - accuracy: 0.8882
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1198 - accuracy: 1.0000
# Epoch 34/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2038 - accuracy: 0.9167
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1306 - accuracy: 0.9902
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1936 - accuracy: 0.9167
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1306 - accuracy: 1.0000
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1343 - accuracy: 0.9348
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2594 - accuracy: 0.9309
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2132 - accuracy: 0.9353
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2424 - accuracy: 0.9348
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1933 - accuracy: 0.9135
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1499 - accuracy: 0.9629
# Epoch 44/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3963 - accuracy: 0.8275
# Epoch 45/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0891 - accuracy: 1.0000
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0886 - accuracy: 0.9803
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0919 - accuracy: 0.9826
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 1.0000
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0887 - accuracy: 0.9941
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1645 - accuracy: 0.9348
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0848 - accuracy: 0.9780
# Epoch 52/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0995 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1462 - accuracy: 0.9545
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1173 - accuracy: 0.9688
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1152 - accuracy: 0.9918
# Epoch 57/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0497 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0536 - accuracy: 1.0000
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0979 - accuracy: 0.9447
# Epoch 61/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0827 - accuracy: 0.9720
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0531 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2233 - accuracy: 0.9629
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0655 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1128 - accuracy: 0.9755
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 0.9780
# Epoch 73/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0390 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0633 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0586 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0471 - accuracy: 0.9918
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1430 - accuracy: 0.9629
# Epoch 81/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0892 - accuracy: 0.9547
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0828 - accuracy: 0.9661
# Epoch 83/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0742 - accuracy: 0.9826
# Epoch 88/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0706 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0215 - accuracy: 0.9892
# Epoch 93/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0848 - accuracy: 0.9447
# Epoch 99/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0870 - accuracy: 0.9688
# Epoch 100/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0290 - accuracy: 0.9892
# Epoch 101/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1231 - accuracy: 0.9545
# Epoch 103/200
# 10/10 [==============================] - ETA: 0s - loss: 7.5906e-04 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0864 - accuracy: 0.9629
# Epoch 105/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0586 - accuracy: 0.9780
# Epoch 106/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1237 - accuracy: 0.9638
# Epoch 109/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0480 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0652 - accuracy: 0.9826
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0983 - accuracy: 0.9447
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9892
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 0.9918
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 0.9862
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9941
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9961
# Epoch 127/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0448 - accuracy: 0.9892
# Epoch 130/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 0.9826
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0278 - accuracy: 0.9918
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0523 - accuracy: 0.9720
# Epoch 151/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1181 - accuracy: 0.9447
# Epoch 153/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0822 - accuracy: 0.9720
# Epoch 165/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0217 - accuracy: 0.9941
# Epoch 167/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1289 - accuracy: 0.9447
# Epoch 169/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 0.9961
# Epoch 174/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0386 - accuracy: 0.9862
# Epoch 175/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 999us/step - loss: 0.0303 - accuracy: 0.9826
# Epoch 177/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 889us/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0369 - accuracy: 0.9862
# Epoch 183/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0481 - accuracy: 0.9780
# Epoch 188/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0140 - accuracy: 0.9892
# Epoch 189/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0182 - accuracy: 0.9941
# Epoch 192/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0133 - accuracy: 1.0000
# model is created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('/Users/acer/Desktop/intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))
def clean_up_sentence(sentence):
    # tokenize the pattern - splitting words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stemming every word - reducing to base form
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    # tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    # bag of words - vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,word in enumerate(words):
            if word == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % word)
    return(np.array(bag))
def predict_class(sentence):
    # filter below  threshold predictions
    p = bag_of_words(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sorting strength probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
#Creating tkinter GUI
import tkinter
from tkinter import *
def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatBox.config(state=NORMAL)
        ChatBox.insert(END, "You: " + msg + '\n\n')
        ChatBox.config(foreground="#446665", font=("Verdana", 12 )) 
        ints = predict_class(msg)
        res = getResponse(ints, intents)
        ChatBox.insert(END, "Bot: " + res + '\n\n')           
        ChatBox.config(state=DISABLED)
        ChatBox.yview(END)
root = Tk()
root.title("Chatbot")
root.geometry("400x500")
root.resizable(width=FALSE, height=FALSE)
#Create Chat window
ChatBox = Text(root, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatBox.config(state=DISABLED)
#Bind scrollbar to Chat window
scrollbar = Scrollbar(root, command=ChatBox.yview, cursor="heart")
ChatBox['yscrollcommand'] = scrollbar.set
#Create Button to send message
SendButton = Button(root, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#f9a602", activebackground="#3c9d9b",fg='#000000',
                    command= send )
#Create the box to enter message
EntryBox = Text(root, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatBox.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
root.mainloop()

# %%
python train_chatbot.py
